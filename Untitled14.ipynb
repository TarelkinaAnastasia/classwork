# %% [markdown]
# <a href="https://colab.research.google.com/github/TarelkinaAnastasia/classwork/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
i = 0
while(a - i):
    print("*"*a)
    i+=1
# Out:
# 5
# *****
# *****
# *****
# *****
# *****

# %%
import pandas as pd

# %%
all = list()
with open("input.txt", "r") as file1:
    full_file = file1.read().splitlines()
    for text in full_file:
        all.append(text.split())
    print(all)
# Out:
# [['0042', 'cat', 'male', 'Pushok', '13.09.2015', '31.12.2016'], ['0043', 'dog', 'female', 'Dora', '29.01.2015', '31.12.2016'], ['0003', 'cat', 'female', 'Eva', '03.03.2017', '31.12.2016']]

# %%
counter_m = counter_f=0
for str in all:
    for i in range (len(str)):
       if str[] == "":
           if str[i+1] == "male":
               counter_m += 1
           else:
                counter_f += 1

# %%
df = pd.DataFrame(all)

# %%
df
# Out:
#       0    1       2       3           4           5
# 0  0042  cat    male  Pushok  13.09.2015  31.12.2016
# 1  0043  dog  female    Dora  29.01.2015  31.12.2016
# 2  0003  cat  female     Eva  03.03.2017  31.12.2016

# %%
def f(x):
    m.atan(-0.0012*x**3+0.4*x**2+0.616*xr+6120)+0.65*m.sin(0.24*x+1.23) - 0.27*m.cos(0.21*x - 0.17) - m.sin(0.34*x + 0.16)/(1+0.03*(x - 370.5)**2)

# %%
years = [i for i in range(1,1001)]
T = [(m.atan(-0.0012*year**3+0.4*year**2+0.616*year+6120)+0.65*m.sin(0.24*year+1.23) - 0.27*m.cos(0.21*year - 0.17) - m.sin(0.34*year + 0.16)/(1+0.03*(year - 370.5)**2)) for year in years]

# %%
import matplotlib.pyplot as plt
import math as m
fig = plt.figure()
plt.plot(years, T)
plt.plot(years, [i*0 for i in range(1,1001)] )

# %%
def D(f, a, b, eps = 1e-5):
    while(b - a) > eps:
        x = (a+b)/2.0

# %%
f = open('books_for_lib.txt')
f.read()
# Out:
# "'Мцыри', 'Преступление и наказание', 'Кортик', 'Бородино', 'Молодая гвардия', 'Евгений Онегин', 'Герой нашего времени', 'Идиот', 'Зойкина квартира', 'Демон', 'Собачье Сердце', 'Сборник романов Достоевского', 'Стихотворения Лермонтова', 'Белая гвардия', 'Мастер и Маргарита', 'Лучшие произведения М.Ю. Лермонтова', 'Горячий снег', 'Дикая собака Динго', 'Беглец', 'Стихотворения Пушкина', 'Василий Теркин', 'Выхожу один я на дорогу', 'Война и Мир', 'Анна Каренина', 'Кинжал','Севастопольские рассказы', 'Бал', 'Ангел', 'Романы Толстого', 'Князь Серебряный','Сердца Трех','По Ком Звонит Колокол', 'Марк Твен', 'Малыш и Карлсон', 'Великий Гетсби', 'Маугли','Мио, Мой Мио', 'На западном фронте без перемен', 'Портрет Дориана Грея', 'Мартин Иден', 'Собор Парижской Богоматери', 'Отверженные', 'Белый Клык', 'Человек, который смеется', 'Детективы Агаты Кристи','Фауст', 'Лучшие стихотворения Киплинга', 'Рубаи Омара Хайяма', 'Сонеты Уильяма Шекспира', 'Гомер: Иллиада', 'Гомер: Одиссея', 'Ворон', 'Уильям
# ...

# %%
all = list()
with open("books_for_lib.txt", "r") as file1:
    for text in file1:
        for book in text.split("', '"):
            all.append(book)
    print(all)
# Out:
# ["'Мцыри", 'Преступление и наказание', 'Кортик', 'Бородино', 'Молодая гвардия', 'Евгений Онегин', 'Герой нашего времени', 'Идиот', 'Зойкина квартира', 'Демон', 'Собачье Сердце', 'Сборник романов Достоевского', 'Стихотворения Лермонтова', 'Белая гвардия', 'Мастер и Маргарита', 'Лучшие произведения М.Ю. Лермонтова', 'Горячий снег', 'Дикая собака Динго', 'Беглец', 'Стихотворения Пушкина', 'Василий Теркин', 'Выхожу один я на дорогу', 'Война и Мир', 'Анна Каренина', 'Кинжал', 'Севастопольские рассказы', 'Бал', 'Ангел', 'Романы Толстого', 'Князь Серебряный', 'Сердца Трех', 'По Ком Звонит Колокол', 'Марк Твен', 'Малыш и Карлсон', 'Великий Гетсби', 'Маугли', 'Мио, Мой Мио', 'На западном фронте без перемен', 'Портрет Дориана Грея', 'Мартин Иден', 'Собор Парижской Богоматери', 'Отверженные', 'Белый Клык', 'Человек, который смеется', 'Детективы Агаты Кристи', 'Фауст', 'Лучшие стихотворения Киплинга', 'Рубаи Омара Хайяма', 'Сонеты Уильяма Шекспира', 'Гомер: Иллиада', 'Гомер: Одиссея', 'Ворон', '
# ...

# %%
len(all)
# Out:
# 60

# %%
for i in range(len(all)//2,3*len(all)//4, 3):
    print(all[i])
# Out:
# Сердца Трех
# Малыш и Карлсон
# Мио, Мой Мио
# Мартин Иден
# Белый Клык

# %%
all = all[len(all)//2:3*len(all)//4:3]

# %%
all
# Out:
# ['Сердца Трех', 'Малыш и Карлсон', 'Мио, Мой Мио', 'Мартин Иден', 'Белый Клык']

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
#df.set_index('PassengerId', inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
d = df.describe()

# %%
df["Family"] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.query('Sex == "male"' and 'Survived == 1').shape[0]
# Out:
# 342

# %%
df.query('Pclass == 3').shape[0]
# Out:
# 491

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#Сколько в каждом классе пассажиров и заменить на элиту средний класс и работяги

# %%
table = pd.pivot_table(df, columns = 'Pclass', index = 'Pclass', aggfunc = np.sum, fill_value = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-a568b4d6c336> in <module>()
# ----> 1 table = pd.pivot_table(df, value = 'Age', columns = 'Pclass', index = 'Pclass', aggfunc = np.sum, fill_value = 0)
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %%
table = pd.pivot_table(df, index = 'Survived', columns = 'Sex', aggfunc=len)

# %%
table
# Out:
#             Age       Cabin      Embarked        Fare        Name       Parch  \
# Sex      female male female male   female male female male female male female
# Survived
# 0            81  468     81  468       81  468     81  468     81  468     81
# 1           233  109    233  109      233  109    233  109    233  109    233
#
#               PassengerId      Pclass       SibSp      Ticket
# Sex      male      female male female male female male female male
# Survived
# 0         468          81  468     81  468     81  468     81  468
# 1         109         233  109    233  109    233  109    233  109

# %%
df[["Survived", "Sex"]].pivot_table(index = 'Survived', columns = 'Sex', aggfunc=len)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
df.loc[df["Pclass"] == 1, "Pclass"] = "Элита"
df.loc[df["Pclass"] == 2, "Pclass"] = "Рабочий класс"
df.loc[df["Pclass"] == 3, "Pclass"] = "Бедные"

# %%
df
# Out:
#      PassengerId  Survived         Pclass  \
# 0              1         0         Бедные
# 1              2         1          Элита
# 2              3         1         Бедные
# 3              4         1          Элита
# 4              5         0         Бедные
# ..           ...       ...            ...
# 886          887         0  Рабочий класс
# 887          888         1          Элита
# 888          889         0         Бедные
# 889          890         1          Элита
# 890          891         0         Бедные
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#количество выживших женщин в зависимости от возраста
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survive'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
